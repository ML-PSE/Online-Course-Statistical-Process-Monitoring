# %% [markdown]
# # **Module**: Python Installation and Basics
# ## **Lecture**: Other Useful Packages for Scientific Data Analysis

# %% [markdown]
# > ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create plot
plt.figure(figsize=(5, 2))
plt.plot(x, y, 'b-', label='sin(x)')
plt.title('Simple Matplotlib Plot')
plt.xlabel('x'), plt.ylabel('sin(x)')
plt.legend(), plt.grid(True)
plt.show()

# %% [markdown]
# > ## Seaborn

# %%
import seaborn as sns

# Load built-in dataset
tips = sns.load_dataset('tips')

# Violin plot
sns.violinplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# > ## Scipy

# %%
import scipy
import numpy as np, matplotlib.pyplot as plt

# Create sample points
x = np.array([0, 2, 4, 6, 8, 10])
y = np.array([1, 3, 2, 4, 3, 5])

# Plot sample points
plt.figure(figsize=(6, 3))
plt.scatter(x, y, color='red', label='Data points', s=100)
plt.title('Sample Points'), plt.grid(True)
plt.legend()
plt.show()

# Create linear interpolation function
f = scipy.interpolate.interp1d(x, y)

# Create points for smooth curve
x_new = np.linspace(0, 10, 100)
y_new = f(x_new)

# Plot
plt.figure(figsize=(6, 3))
plt.scatter(x, y, color='red', label='Data points', s=100)
plt.plot(x_new, y_new, 'b-', label='Linear interpolation')
plt.title('Linear Interpolation Example'), plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# > ## Statsmodels

# %%
import statsmodels.api as sm
import numpy as np

# Create sample data
X = np.random.normal(size=(100,2))
y = np.random.normal(size=(100,))

# Fit linear regression
model = sm.OLS(y, X).fit()
print(model.summary())  # Print coefficient table only: model.summary().tables[1]
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.003
# Model:                            OLS   Adj. R-squared (uncentered):             -0.018
# Method:                 Least Squares   F-statistic:                             0.1299
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):                       0.878
# Time:                        18:40:09   Log-Likelihood:                         -133.77
# No. Observations:                 100   AIC:                                      271.5
# Df Residuals:                      98   BIC:                                      276.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# > ## Scikit-learn

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load the iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Create and train the model
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X, y)

# Make predictions and compute accuracy
predictions = rf.predict(X)
accuracy = accuracy_score(y, predictions) * 100

print(f"Model Accuracy on training dataset: {accuracy}%")
# Out:
# Model Accuracy on training dataset: 100.0%
